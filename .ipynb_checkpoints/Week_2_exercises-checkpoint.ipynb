# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import pymc3 as pm
import arviz as az

from scipy import stats

from causalgraphicalmodels import CausalGraphicalModel

import warnings

print('Running on pymc3 version {}'.format(pm.__version__))


warnings.filterwarnings('ignore')
# %config Inline.figure_format = 'retina'
az.style.use("arviz-darkgrid")
# Out:
# Running on pymc3 version 3.11.2

# %% [markdown]
# ## Ex. 1

# %%
#read and filter df
df = pd.read_csv('data/Howell1.csv', sep=';')
df1 = df[df.age >= 18]
df1['height_s'] = df1.height - np.mean(df1.height)

# %%
df1.head()
# Out:
#     height     weight   age  male   height_s
# 0  151.765  47.825606  63.0     1  -2.832093
# 1  139.700  36.485807  63.0     0 -14.897093
# 2  136.525  31.864838  65.0     0 -18.072093
# 3  156.845  53.041914  41.0     1   2.247907
# 4  145.415  41.276872  51.0     0  -9.182093

# %%
df1.weight.mean()
# Out:
# 44.99048551988636

# %%
#select priors alpha: weight when height is at average
x = np.linspace(30, 100, 100)
y = stats.norm.pdf(x, 60, 10)
plt.plot(x, y)

# %%
#priors beta
x = np.linspace(-10, 10, 100)
y = stats.lognorm.pdf(x, 1)
plt.plot(x, y)

# %%
#prior sigma
x = np.linspace(0, 30, 100)
y = stats.uniform.pdf(x, 0, 10)
plt.plot(x, y)

# %% [markdown]
# Model definition
#
# \begin{split}\begin{aligned}
# W_i  &\sim Normal(\mu_i, \sigma) \\
# \mu_i &= \alpha + \beta_H H_i \\
# \alpha &\sim Normal(60, 10) \\
# \beta_H &\sim LogNormal(0, 1) \\
# \sigma &\sim Uniform(0, 10)
# \end{aligned}\end{split}

# %%
with pm.Model() as w_2_1:
    
    #define input data
    height_s = pm.Data("height_s", df1['height_s'])
    weight = pm.Data("weight", df1['weight'])

    #define priors
    alpha = pm.Normal("alpha", mu=60, sd=10)
    beta_h = pm.Lognormal("beta_h", sd=1)
    sigma = pm.Uniform("sigma", 0, 10)

    #define regression
    mu = pm.Deterministic("mu", alpha + beta_h*height_s)
    
    weight_hat = pm.Normal("weight_hat", mu=mu, sd=sigma, observed=weight)
    
    #prior sampling
    prior = pm.sample_prior_predictive()

# %%
#simulate from priors

x = np.linspace(130, 170, 30)
x_bar = 150

fig, ax = plt.subplots()
ax.set_xlim(130, 170)
ax.set_ylim(10,90)
ax.set_xlabel('height')
ax.set_ylabel('expected weight')

for a, b in zip(prior['alpha'][:50], prior['beta_h'][:50]):
    y = a + b*(x-x_bar)
    plt.plot(x, y, color='black', alpha=0.3)

# %%
with w_2_1:
    trace_2_1 = pm.sample(1000, tune=1000,return_inferencedata=False)
    posterior_2_1 = pm.sample_posterior_predictive(trace=trace_2_1)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, beta_h, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:02<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 11 seconds.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:19<00:00]
#     </div>

# %%
var_names = ['alpha', 'beta_h', 'sigma']

with w_2_1:
    summary = az.summary(trace_2_1, var_names=var_names)
summary
# Out:
#           mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha   44.995  0.229  44.585   45.432      0.003    0.002    5425.0
# beta_h   0.629  0.030   0.575    0.686      0.000    0.000    5224.0
# sigma    4.256  0.164   3.950    4.557      0.002    0.002    6162.0
#
#         ess_tail  r_hat
# alpha     2925.0    1.0
# beta_h    2995.0    1.0
# sigma     2653.0    1.0

# %%
with w_2_1:
    az.plot_trace(trace_2_1, var_names=var_names)

# %%
#validate with simulation

np.random.seed(seed=233423)

alpha = 70
beta = 0.5
sigma = 5
n_individuals = 100

H = stats.uniform.rvs(loc=130, scale=60, size=n_individuals)
mu = alpha + beta*(H-H.mean())
W = stats.norm.rvs(loc=mu,scale=5, size=n_individuals)

H_s = H - H.mean()

# %%
with pm.Model() as w_2_2:
    
    #define input data
    height_s = pm.Data("height_s", H_s)
    weight = pm.Data("weight", W)

    #define priors
    alpha = pm.Normal("alpha", mu=60, sd=10)
    beta_h = pm.Lognormal("beta_h", sd=1)
    sigma = pm.Uniform("sigma", 0, 10)

    #define regression
    mu = pm.Deterministic("mu", alpha + beta_h*height_s)
    
    weight_hat = pm.Normal("weight_hat", mu=mu, sd=sigma, observed=weight)
    
    #prior sampling
    prior = pm.sample_prior_predictive()
    trace_2_2 = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, beta_h, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:01<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 10 seconds.

# %%
var_names = ['alpha', 'beta_h', 'sigma']

with w_2_2:
    summary = az.summary(trace_2_2, var_names=var_names)
summary
# Out:
#           mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha   70.224  0.484  69.293   71.081      0.007    0.005    5168.0
# beta_h   0.507  0.027   0.455    0.557      0.000    0.000    4743.0
# sigma    4.797  0.358   4.145    5.483      0.005    0.004    4658.0
#
#         ess_tail  r_hat
# alpha     2428.0    1.0
# beta_h    2815.0    1.0
# sigma     2470.0    1.0

# %%
#plot sample
#plot posterior mean
#plot uncertainity of the mean
#plot uncertainity of the predictions

mu_mean = trace_2_1['mu'].mean(axis=0)

fig, ax = plt.subplots()
ax.set_xlabel('height')
ax.set_ylabel('weight')
    
ax.scatter(df1.height, df1.weight) 
ax.plot(df1.height, mu_mean, color = 'r')
az.plot_hdi(df1.height, trace_2_1['mu'])
az.plot_hdi(df1.height, posterior_2_1['weight_hat']);

# %%
#predict for new data
individual = [x for x in range(1, 4)]
height = [140, 160, 175]
expected_weight = np.nan
hdi_low = np.nan
hdi_high = np.nan

# %%
df_pred = pd.DataFrame({'individual':individual,
                        'height':height,
                        'expected_weight':expected_weight,
                        'hdi_low':hdi_low,
                        'hdi_high':hdi_high})
df_pred
# Out:
#    individual  height  expected_weight  hdi_low  hdi_high
# 0           1     140              NaN      NaN       NaN
# 1           2     160              NaN      NaN       NaN
# 2           3     175              NaN      NaN       NaN

# %%
df_pred['height_s'] = df_pred['height'] - df1['height'].mean()

# %%
with w_2_1:
    pm.set_data({
    "height_s": df_pred['height_s']
    })
    
    height_pred_data = pm.sample_posterior_predictive(trace_2_1)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:21<00:00]
#     </div>

# %%
df_pred['expected_weight'] = height_pred_data['weight_hat'].mean(axis=0)
df_pred[['hdi_low', 'hdi_high']] = az.hdi(height_pred_data['weight_hat'])

# %%
df_pred
# Out:
#    individual  height  expected_weight    hdi_low   hdi_high   height_s
# 0           1     140        35.735428  27.534951  43.809856 -14.597093
# 1           2     160        48.403962  40.215475  56.064247   5.402907
# 2           3     175        57.722184  49.407548  65.671223  20.402907

# %% [markdown]
# ## Ex. 2

# %%
df2 = df[df.age <13]

# %%
df2.shape
# Out:
# (146, 4)

# %%
df2.head()
# Out:
#     height     weight   age  male
# 18  121.92  19.617854  12.0     1
# 19  105.41  13.947954   8.0     0
# 20   86.36  10.489315   6.5     0
# 24  109.22  15.989118   7.0     0
# 30  114.30  17.860185  11.0     1

# %%
df2['height_s'] = df2['height'] - df2['height'].mean()

# %%
#select priors alpha: weight when height is at average
x = np.linspace(0, 50, 100)
y = stats.norm.pdf(x, 20, 10)
plt.plot(x, y)

# %%
#priors beta
x = np.linspace(-10, 10, 100)
y = stats.lognorm.pdf(x, 1)
plt.plot(x, y)

# %%
#prior sigma
x = np.linspace(0, 30, 100)
y = stats.uniform.pdf(x, 0, 10)
plt.plot(x, y)

# %% [markdown]
# Model definition
#
# \begin{split}\begin{aligned}
# W_i  &\sim Normal(\mu_i, \sigma) \\
# \mu_i &= \alpha + \beta_H H_i \\
# \alpha &\sim Normal(20, 10) \\
# \beta_H &\sim LogNormal(0, 1) \\
# \sigma &\sim Uniform(0, 10)
# \end{aligned}\end{split}

# %%
with pm.Model() as w_2_3:
    
    #define input data
    height_s = pm.Data("height_s", df2['height_s'])
    weight = pm.Data("weight", df2['weight'])

    #define priors
    alpha = pm.Normal("alpha", mu=20, sd=10)
    beta_h = pm.Lognormal("beta_h", sd=0.5)
    sigma = pm.Uniform("sigma", 0, 10)

    #define regression
    mu = pm.Deterministic("mu", alpha + beta_h*height_s)
    
    weight_hat = pm.Normal("weight_hat", mu=mu, sd=sigma, observed=weight)
    
    #prior sampling
    prior_2_3 = pm.sample_prior_predictive()

# %%
#simulate from priors

x = np.linspace(50, 150, 30)
x_bar = 100

fig, ax = plt.subplots()
ax.set_xlim(50, 150)
ax.set_ylim(0,80)
ax.set_xlabel('height')
ax.set_ylabel('expected weight')

for a, b in zip(prior_2_3['alpha'][:50], prior_2_3['beta_h'][:50]):
    y = a + b*(x-x_bar)
    plt.plot(x, y, color='black', alpha=0.3)

# %%
with w_2_3:
    trace_2_3 = pm.sample(1000, tune=1000,return_inferencedata=False)
    posterior_2_3 = pm.sample_posterior_predictive(trace=trace_2_3)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, beta_h, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:01<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 11 seconds.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:19<00:00]
#     </div>

# %%
var_names = ['alpha', 'beta_h', 'sigma']

with w_2_3:
    summary = az.summary(trace_2_3, var_names=var_names)
summary
# Out:
#           mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha   14.694  0.128  14.457   14.935      0.002    0.001    5295.0
# beta_h   0.258  0.006   0.247    0.269      0.000    0.000    5390.0
# sigma    1.506  0.092   1.353    1.694      0.001    0.001    5375.0
#
#         ess_tail  r_hat
# alpha     2930.0    1.0
# beta_h    2939.0    1.0
# sigma     2862.0    1.0

# %%
#plot sample
#plot posterior mean
#plot uncertainity of the mean
#plot uncertainity of the predictions

mu_mean = trace_2_3['mu'].mean(axis=0)

fig, ax = plt.subplots()
ax.set_xlabel('height')
ax.set_ylabel('weight')
    
ax.scatter(df2.height, df2.weight) 
ax.plot(df2.height, mu_mean, color = 'r')
az.plot_hdi(df2.height, trace_2_3['mu'])
az.plot_hdi(df2.height, posterior_2_3['weight_hat']);

# %% [markdown]
# ## Ex. 3

# %%
df2.head()
# Out:
#     height     weight   age  male   height_s
# 18  121.92  19.617854  12.0     1  23.109271
# 19  105.41  13.947954   8.0     0   6.599271
# 20   86.36  10.489315   6.5     0 -12.450729
# 24  109.22  15.989118   7.0     0  10.409271
# 30  114.30  17.860185  11.0     1  15.489271

# %%
sex_id = pd.factorize(df2.male)[0]
sex_idx = pd.factorize(df2.male)[1]

# %%
with pm.Model() as w_2_4:
    
    #define input data
    height_s = pm.Data("height_s", df2['height_s'])
    weight = pm.Data("weight", df2['weight'])
    sex = pm.Data("sex", sex_id)

    #define priors
    alpha = pm.Normal("alpha", mu=20, sd=10, shape=len(sex_idx))
    beta_h = pm.Lognormal("beta_h", sd=1, shape=len(sex_idx))
    sigma = pm.Uniform("sigma", 0, 10)

    #define regression
    mu = pm.Deterministic("mu", alpha[sex] + beta_h[sex]*height_s)
    
    weight_hat = pm.Normal("weight_hat", mu=mu[sex], sd=sigma, observed=weight)
    
    #prior sampling
    prior_2_4 = pm.sample_prior_predictive()

# %%
with w_2_4:
    trace_2_4 = pm.sample(1000, tune=1000,return_inferencedata=False)
    posterior_2_4 = pm.sample_posterior_predictive(trace=trace_2_4)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, beta_h, alpha]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:05<00:00 Sampling 4 chains, 348 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 14 seconds.
# There were 28 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 90 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.612904867966526, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 60 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 170 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.5164108715773795, but should be close to 0.8. Try to increase the number of tuning steps.
# The estimated number of effective samples is smaller than 200 for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:19<00:00]
#     </div>

# %%
#check summary
var_names = ['alpha', 'beta_h', 'sigma']

with w_2_4:
    summary = az.summary(trace_2_4, var_names=var_names)
summary
# Out:
#             mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha[0]   7.207  4.649  -1.138   14.962      0.573    0.407      77.0
# alpha[1]   9.618  2.991   3.557   13.743      0.304    0.215     112.0
# beta_h[0]  0.362  0.198   0.052    0.734      0.024    0.019      78.0
# beta_h[1]  0.654  0.446   0.055    1.515      0.044    0.033     113.0
# sigma      5.769  0.339   5.134    6.406      0.020    0.014     285.0
#
#            ess_tail  r_hat
# alpha[0]       40.0   1.01
# alpha[1]       73.0   1.02
# beta_h[0]      42.0   1.01
# beta_h[1]      90.0   1.02
# sigma         434.0   1.01

# %%
with w_2_4:
    az.plot_trace(trace_2_4, var_names=var_names)
